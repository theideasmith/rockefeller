# %% [markdown]
# One of the ideas I spoke about with Christoph is comparing the training details of RTRL's trained in temporal contexts vs those trained with randomly uncorrelated data. Training in context enables fine tuning of contextual information, while training on orthogonal data makes the network more versatile.
#
# Some tasks:
# 1. The objective here is to see if I can successfully train the RTRL to play the standard game of life. Because it is also a temporal

# %%
from pylab import *
from scipy.cluster import vq
from Cluster import genCorrelationMatrix
import scipy.cluster.hierarchy as sch  


# %matplotlib inline
def index_min(values):
    return min(xrange(len(values)),key=values.__getitem__)

# Distance by the euclidean metric
def ME(A,B): return np.sqrt(np.sum((B-A)**2))

solutions = load('./1000_weights.npy').reshape((1000, 9*6))[:,1:]

# %%
from Cluster import genCorrelationMatrix
from scipy import stats
globalhist = np.histogram(-genCorrelationMatrix(solutions).flatten(), bins=100)
plot(globalhist[1][1:], globalhist[0])

# %%
# The number of clusters
K = 6
def whiten(obs):
     std_dev = std(obs)
     return obs / std_dev
kmeanable = whiten(solutions)
centroids, labels = vq.kmeans2(kmeanable, k=K)

zipped = array([range(len(labels)), labels]).T
assigned_sorted = zipped[zipped[:, 1].argsort()]
assigned = array([assigned_sorted[assigned_sorted[:,1] ==i][:,0] for i in arange(K)])
representatives = [] #map(lambda a: np.average(solutions[a],axis=0), assigned)

for i in xrange(len(centroids)):
    distances = map(lambda a: ME(solutions[a], centroids[i]), assigned[i])
    if (len(distances)!=0): 
        amin = argmin(distances)
        representatives.append(solutions[assigned[i][amin]])
# Out:
# 15.2077574889
# 14.5431557155
# 15.0678963212
# 14.9468056348
# 14.7858386765
# 14.8204554295

# %% [markdown]
# So we have the 6 neurons most highly representative of their respective clusters.
# Now we need to compare the permutation similarityt to see if the fact that 6 clusters exist is an artifact of the permutability of the hidden neurons.

# %%
from itertools import permutations
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
# The number of hidden neurons
p = list(permutations(range(3,6),3))
permutes = [ [0,1,2] + list(j) for j in p ]
permutation_distances = []



c = len(representatives)
for i in xrange(0,c):
    # Distances from representatives[i]
    # permutation[js] to other representatives
    pdists = []
    for h in xrange(0,c):
        if (h==i): continue

        # Distances from ith permutation of representative[j]
        # to other representatives
        permdists = []
        for j in xrange(len(p)):
            temp = zeros(54)
            temp[1:] = representatives[i]
            a = temp.reshape((6,9))[permutes[j]].reshape(54)[1:]
            b = representatives[h]
            permdists.append(ME(a,b))
        pdists.append(permdists)
    permutation_distances.append(pdists)

# %%
f, ax = subplots(3,4,figsize=(30,15))

iths=['th','st','nd','rd','th','th']
for i in xrange(0,len(permutation_distances)):
    pdists = permutation_distances[i]
    print stats.mode(array(pdists),axis=None)[0][0]

#     plt.figure()
#     f,ax = subplots(1,2,figsize=(15,5))
#     ax[0].set_title("Correlations for permutations of {0}{1} cluster to other representatives".format(i,iths[i]))
#     pc = ax[0].pcolormesh(pdists) 
#     div = make_axes_locatable(ax[0])
#     # Append axes to the right of ax3, with 20% width of ax3
#     cax = div.append_axes("right", size="3%", pad=0.05)
#     # Create colorbar in the appended axes
#     # Tick locations can be set with the kwarg `ticks`
#     # and the format of the ticklabels with kwarg `format`
#     cbar = plt.colorbar(pc, cax=cax, ticks=MultipleLocator(1), format="%.0f")
#     ax[1].set_title("Distribution of permuations distances for {0}{1} cluster".format(i,iths[i]))
#     ax[1].hist(array(pdists).flatten(),bins=5)

    ind = (i)%3
    b = 1 if i <3 else 3
    a = 0 if i <3 else 2
    ax[ind,a].set_title("Correlations for permutations of {0}{1} cluster to other representatives".format(ind,iths[ind]))
    pc = ax[ind, a].pcolormesh(pdists) 
    div = make_axes_locatable(ax[ind,a])
    # Append axes to the right of ax3, with 20% width of ax3
    cax = div.append_axes("right", size="3%", pad=0.05)
    # Create colorbar in the appended axes
    # Tick locations can be set with the kwarg `ticks`
    # and the format of the ticklabels with kwarg `format`
    cbar = plt.colorbar(pc, cax=cax, ticks=MultipleLocator(1), format="%.0f")

    
    ax[ind,b].set_title("Distribution of permuations distances for {0}{1} cluster".format(ind,iths[ind]))
    ax[ind,b].hist(array(pdists).flatten(),bins=100)
    
tight_layout()

plt.savefig('./permutations_distributions.jpg',dpi=400)
# Out:
# 20.378992918
# 18.5404333225
# 14.1595534125
# 14.1595534125
# 15.6804505739
# 15.6804505739

# %%
print "Percentile of distance frequencies for permutation of ith weight matrix:"
for d in permutation_distances:
    print "--------"

#     a = stats.mode(array(d),axis=None)[0][0]
    a = np.average(array(d))
    percentile = stats.percentileofscore(globalhist[0],a )

    print "Percentile: {0}".format(percentile)
    print "  Distance: {0}".format(a)
# Out:
# Percentile of distance frequencies for permutation of ith weight matrix:
# --------
# Percentile: 7.0
#   Distance: 23.6134042733
# --------
# Percentile: 7.0
#   Distance: 21.8034675413
# --------
# Percentile: 7.0
#   Distance: 22.322188958
# --------
# Percentile: 7.0
#   Distance: 23.4349978908
# --------
# Percentile: 7.0
#   Distance: 22.2423874209
# --------
# Percentile: 7.0
#   Distance: 21.8238093541

# %% [markdown]
# From this we can see that the distribution of permutation distances falls on the lower end of the spectrum.

# %%
import networkx as nx
correlations = genCorrelationMatrix(centroids)
G=nx.from_numpy_matrix(correlations)
for i in range(len(G.nodes())):
    for j in range(len(solutions)):
        G.add_node('solution_'+str(j))
        G.add_edge(i,'solution'+str(j), weight=-ME(centroids[i],solutions[j]))
        
plt.figure(figsize=(10,10))
nx.draw_shell(G)

# %%
# c = map(lambda a: np.average(solutions[a],axis=0), assigned)
map(lambda a: ME(solutions[a], c[i]), assigned[i])
# map(lambda a: ME(*a), zip(centroids, c))
# Out:
# [13.891829137079062,
#  11.39500797618425,
#  13.751520575623958,
#  12.21641535470015,
#  13.240454643949894,
#  12.748021405549174,
#  12.115975520763076,
#  13.375429487297479,
#  13.138430495640298,
#  13.875355832638901,
#  12.643441822282151,
#  13.211441111851952,
#  13.386811217911585,
#  13.579439113107073,
#  12.471924213142389,
#  11.790941483209187,
#  12.835852548290346,
#  15.350396470262893,
#  11.204168803925581,
